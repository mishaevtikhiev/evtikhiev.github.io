# %% [markdown]
# # Travelling map

# %%
# !pip install folium

# %%
import folium

# %%
m = folium.Map(location=[28, 55], zoom_start=2)

# %%
tooltip = "Click me!"
color_home = "red"
icon_home = "home"
color_living = "orange"
icon_living = "tower"
color_travel = "green"
icon_travel = "tree-deciduous"
color_work = "blue"
icon_work = "briefcase"
color_transit = "lightgray"
icon_transit = "plane"

# %%
folium.Marker(
    [59.938948, 30.315950], 
    popup="<b>Saint Petersburg</b><br>April 1997", 
    tooltip=tooltip, 
    icon=folium.Icon(color=color_home, icon=icon_home)
).add_to(m)

folium.Marker(
    [59.717387, 30.397206], 
    popup="<b>Pushkin</b><br>June 2004", 
    tooltip=tooltip, 
    icon=folium.Icon(color=color_home, icon=icon_home)
).add_to(m)

folium.Marker(
    [59.682742, 30.449041], 
    popup="<b>Pavlovsk</b><br>December 2007", 
    tooltip=tooltip, 
    icon=folium.Icon(color=color_home, icon=icon_home)
).add_to(m)

folium.Marker(
    [51.500738, -0.124571], 
    popup="<b>London</b><br>November 2012", 
    tooltip=tooltip, 
    icon=folium.Icon(color=color_work, icon=icon_work)
).add_to(m)

folium.Marker(
    [51.145870, 0.874715], 
    popup="<b>Ashford</b><br>November 2012", 
    tooltip=tooltip, 
    icon=folium.Icon(color=color_work, icon=icon_work)
).add_to(m)

folium.Marker(
    [54.070540, 37.526802], 
    popup="<b>Yasnaya Polyana</b><br>October 2013", 
    tooltip=tooltip, 
    icon=folium.Icon(color=color_travel, icon=icon_travel)
).add_to(m)

folium.Marker(
    [53.369554, 36.629296], 
    popup="<b>Spasskoye-Lutovinovo</b><br>October 2013", 
    tooltip=tooltip, 
    icon=folium.Icon(color=color_travel, icon=icon_travel)
).add_to(m)

folium.Marker(
    [59.772583, 30.791796], 
    popup="<b>Otradnoye</b><br>June 2014", 
    tooltip=tooltip, 
    icon=folium.Icon(color=color_home, icon=icon_home)
).add_to(m)

folium.Marker(
    [61.868079, 28.885904], 
    popup="<b>Savonlinna</b><br>July 2014", 
    tooltip=tooltip, 
    icon=folium.Icon(color=color_travel, icon=icon_travel)
).add_to(m)

folium.Marker(
    [60.867882, 26.703927], 
    popup="<b>Kouvola</b><br>August 2014", 
    tooltip=tooltip, 
    icon=folium.Icon(color=color_travel, icon=icon_travel)
).add_to(m)

folium.Marker(
    [59.742486, 30.594710], 
    popup="<b>Kolpino</b><br>February 2015", 
    tooltip=tooltip, 
    icon=folium.Icon(color=color_home, icon=icon_home)
).add_to(m)

folium.Marker(
    [55.753403, 37.620834], 
    popup="<b>Moscow</b><br>February 2015", 
    tooltip=tooltip, 
    icon=folium.Icon(color=color_travel, icon=icon_travel)
).add_to(m)

folium.Marker(
    [60.095787, 29.954779], 
    popup="<b>Sestroretsk</b><br>March 2015", 
    tooltip=tooltip, 
    icon=folium.Icon(color=color_home, icon=icon_home)
).add_to(m)

folium.Marker(
    [59.561738, 30.115215], 
    popup="<b>Gatchina</b><br>September 2015", 
    tooltip=tooltip, 
    icon=folium.Icon(color=color_home, icon=icon_home)
).add_to(m)

folium.Marker(
    [60.192213, 29.701862], 
    popup="<b>Zelenogorsk</b><br>April 2016", 
    tooltip=tooltip, 
    icon=folium.Icon(color=color_home, icon=icon_home)
).add_to(m)

folium.Marker(
    [58.521272, 31.276110], 
    popup="<b>Veliky Novgorod</b><br>May 2016", 
    tooltip=tooltip, 
    icon=folium.Icon(color=color_travel, icon=icon_travel)
).add_to(m)

folium.Marker(
    [50.846792, 4.352176], 
    popup="<b>Brussels</b><br>November 2016", 
    tooltip=tooltip, 
    icon=folium.Icon(color=color_work, icon=icon_work)
).add_to(m)

folium.Marker(
    [51.208326, 3.226681], 
    popup="<b>Bruges</b><br>November 2016", 
    tooltip=tooltip, 
    icon=folium.Icon(color=color_travel, icon=icon_travel)
).add_to(m)

folium.Marker(
    [50.717609, 4.398007], 
    popup="<b>Waterloo</b><br>November 2016", 
    tooltip=tooltip, 
    icon=folium.Icon(color=color_travel, icon=icon_travel)
).add_to(m)

folium.Marker(
    [-26.192572, 28.036835], 
    popup="<b>Johannesburg</b><br>November 2016", 
    tooltip=tooltip, 
    icon=folium.Icon(color=color_work, icon=icon_work)
).add_to(m)

folium.Marker(
    [60.167582, 24.942142], 
    popup="<b>Helsinki</b><br>May 2017", 
    tooltip=tooltip, 
    icon=folium.Icon(color=color_travel, icon=icon_travel)
).add_to(m)

folium.Marker(
    [60.393130, 25.665340], 
    popup="<b>Porvoo</b><br>May 2017", 
    tooltip=tooltip, 
    icon=folium.Icon(color=color_travel, icon=icon_travel)
).add_to(m)

folium.Marker(
    [59.991425, 29.778873], 
    popup="<b>Kronstadt</b><br>June 2017", 
    tooltip=tooltip, 
    icon=folium.Icon(color=color_home, icon=icon_home)
).add_to(m)

folium.Marker(
    [56.310660, 38.130471], 
    popup="<b>Sergiev Posad</b><br>July 2017", 
    tooltip=tooltip, 
    icon=folium.Icon(color=color_travel, icon=icon_travel)
).add_to(m)

folium.Marker(
    [56.736588, 38.852133], 
    popup="<b>Pereslavl-Zalessky</b><br>July 2017", 
    tooltip=tooltip, 
    icon=folium.Icon(color=color_travel, icon=icon_travel)
).add_to(m)

folium.Marker(
    [57.184736, 39.416595], 
    popup="<b>Rostov</b><br>July 2017", 
    tooltip=tooltip, 
    icon=folium.Icon(color=color_travel, icon=icon_travel)
).add_to(m)

folium.Marker(
    [57.621452, 39.888206], 
    popup="<b>Yaroslavl</b><br>July 2017", 
    tooltip=tooltip, 
    icon=folium.Icon(color=color_travel, icon=icon_travel)
).add_to(m)

folium.Marker(
    [57.767677, 40.926229], 
    popup="<b>Kostroma</b><br>July 2017", 
    tooltip=tooltip, 
    icon=folium.Icon(color=color_travel, icon=icon_travel)
).add_to(m)

folium.Marker(
    [57.001257, 40.973717], 
    popup="<b>Ivanovo</b><br>July 2017", 
    tooltip=tooltip, 
    icon=folium.Icon(color=color_travel, icon=icon_travel)
).add_to(m)

folium.Marker(
    [56.138433, 40.399936], 
    popup="<b>Vladimir</b><br>July 2017", 
    tooltip=tooltip, 
    icon=folium.Icon(color=color_travel, icon=icon_travel)
).add_to(m)

folium.Marker(
    [56.421229, 40.447081], 
    popup="<b>Suzdal</b><br>July 2017", 
    tooltip=tooltip, 
    icon=folium.Icon(color=color_travel, icon=icon_travel)
).add_to(m)

folium.Marker(
    [54.706214, 20.512923], 
    popup="<b>Kaliningrad</b><br>August 2018", 
    tooltip=tooltip, 
    icon=folium.Icon(color=color_travel, icon=icon_travel)
).add_to(m)

folium.Marker(
    [54.640040, 21.806177], 
    popup="<b>Chernyakhovsk</b><br>August 2018", 
    tooltip=tooltip, 
    icon=folium.Icon(color=color_travel, icon=icon_travel)
).add_to(m)

folium.Marker(
    [54.589787, 22.202236], 
    popup="<b>Gusev</b><br>August 2018", 
    tooltip=tooltip, 
    icon=folium.Icon(color=color_travel, icon=icon_travel)
).add_to(m)

folium.Marker(
    [54.644043, 19.893790], 
    popup="<b>Baltiysk</b><br>August 2018", 
    tooltip=tooltip, 
    icon=folium.Icon(color=color_travel, icon=icon_travel)
).add_to(m)

folium.Marker(
    [54.868306, 19.938658], 
    popup="<b>Yantarny</b><br>August 2018", 
    tooltip=tooltip, 
    icon=folium.Icon(color=color_travel, icon=icon_travel)
).add_to(m)

folium.Marker(
    [54.959545, 20.479084], 
    popup="<b>Zelenogradsk</b><br>August 2018", 
    tooltip=tooltip, 
    icon=folium.Icon(color=color_travel, icon=icon_travel)
).add_to(m)

folium.Marker(
    [54.514392, 36.256562], 
    popup="<b>Kaluga</b><br>May 2019", 
    tooltip=tooltip, 
    icon=folium.Icon(color=color_travel, icon=icon_travel)
).add_to(m)

folium.Marker(
    [57.821731, 28.329065], 
    popup="<b>Pskov</b><br>June 2021", 
    tooltip=tooltip, 
    icon=folium.Icon(color=color_travel, icon=icon_travel)
).add_to(m)

folium.Marker(
    [57.022699, 28.914927], 
    popup="<b>Pushkinskiye Gory</b><br>June 2021", 
    tooltip=tooltip, 
    icon=folium.Icon(color=color_travel, icon=icon_travel)
).add_to(m)

folium.Marker(
    [59.881924, 30.983610], 
    popup="<b>Kirovsk</b><br>November 2019", 
    tooltip=tooltip, 
    icon=folium.Icon(color=color_living, icon=icon_living)
).add_to(m)

folium.Marker(
    [59.944291, 31.033289], 
    popup="<b>Shlisselburg</b><br>December 2019", 
    tooltip=tooltip, 
    icon=folium.Icon(color=color_home, icon=icon_home)
).add_to(m)

folium.Marker(
    [60.712926, 28.733257], 
    popup="<b>Vyborg</b><br>October 2020", 
    tooltip=tooltip, 
    icon=folium.Icon(color=color_home, icon=icon_home)
).add_to(m)

folium.Marker(
    [61.699749, 30.692326], 
    popup="<b>Sortavala</b><br>May 2021", 
    tooltip=tooltip, 
    icon=folium.Icon(color=color_travel, icon=icon_travel)
).add_to(m)

folium.Marker(
    [61.388734, 30.944909], 
    popup="<b>Valaam</b><br>May 2021", 
    tooltip=tooltip, 
    icon=folium.Icon(color=color_travel, icon=icon_travel)
).add_to(m)

folium.Marker(
    [58.731808, 29.848915], 
    popup="<b>Luga</b><br>July 2019", 
    tooltip=tooltip, 
    icon=folium.Icon(color=color_work, icon=icon_work)
).add_to(m)

folium.Marker(
    [41.716969, 44.787393], 
    popup="<b>Tbilisi</b><br>October 2019", 
    tooltip=tooltip, 
    icon=folium.Icon(color=color_work, icon=icon_work)
).add_to(m)

folium.Marker(
    [56.475355, 84.950201], 
    popup="<b>Tomsk</b><br>August 2019", 
    tooltip=tooltip, 
    icon=folium.Icon(color=color_travel, icon=icon_travel)
).add_to(m)

folium.Marker(
    [56.326158, 44.003545], 
    popup="<b>Nizhny Novgorod</b><br>February 2018", 
    tooltip=tooltip, 
    icon=folium.Icon(color=color_travel, icon=icon_travel)
).add_to(m)

folium.Marker(
    [59.878285, 29.892599], 
    popup="<b>Petergof</b><br>October 2012", 
    tooltip=tooltip, 
    icon=folium.Icon(color=color_home, icon=icon_home)
).add_to(m)

folium.Marker(
    [60.452910, 28.721317], 
    popup="<b>Glebychevo</b><br>June 1999", 
    tooltip=tooltip, 
    icon=folium.Icon(color=color_home, icon=icon_home)
).add_to(m)

folium.Marker(
    [59.954031, 29.098551], 
    popup="<b>Kandikyulya</b><br>June 2001", 
    tooltip=tooltip, 
    icon=folium.Icon(color=color_home, icon=icon_home)
).add_to(m)

folium.Marker(
    [59.601187, 30.160734], 
    popup="<b>Vaya</b><br>May 2002", 
    tooltip=tooltip, 
    icon=folium.Icon(color=color_home, icon=icon_home)
).add_to(m)

folium.Marker(
    [59.628242, 30.414084], 
    popup="<b>Kommunar</b><br>May 2002", 
    tooltip=tooltip, 
    icon=folium.Icon(color=color_home, icon=icon_home)
).add_to(m)

folium.Marker(
    [59.350843, 30.070585], 
    popup="<b>Siversky</b><br>April 2004", 
    tooltip=tooltip, 
    icon=folium.Icon(color=color_home, icon=icon_home)
).add_to(m)

folium.Marker(
    [59.410492, 30.340363], 
    popup="<b>Vyritsa</b><br>April 2004", 
    tooltip=tooltip, 
    icon=folium.Icon(color=color_home, icon=icon_home)
).add_to(m)

folium.Marker(
    [60.494574, 30.268424], 
    popup="<b>Orekhovo</b><br>June 2006", 
    tooltip=tooltip, 
    icon=folium.Icon(color=color_home, icon=icon_home)
).add_to(m)

folium.Marker(
    [60.382123, 30.355684], 
    popup="<b>Vaskelovo</b><br>July 2008", 
    tooltip=tooltip, 
    icon=folium.Icon(color=color_home, icon=icon_home)
).add_to(m)

folium.Marker(
    [60.682680, 30.064464], 
    popup="<b>Ovragi</b><br>May 2009", 
    tooltip=tooltip, 
    icon=folium.Icon(color=color_home, icon=icon_home)
).add_to(m)

folium.Marker(
    [60.359286, 28.990139], 
    popup="<b>Krasnaya Dolina</b><br>May 2011", 
    tooltip=tooltip, 
    icon=folium.Icon(color=color_home, icon=icon_home)
).add_to(m)

folium.Marker(
    [60.337448, 28.984614], 
    popup="<b>Ryabovo</b><br>June 2012", 
    tooltip=tooltip, 
    icon=folium.Icon(color=color_home, icon=icon_home)
).add_to(m)

folium.Marker(
    [51.249206, 0.613427], 
    popup="<b>Leeds, Kent</b><br>November 2012", 
    tooltip=tooltip, 
    icon=folium.Icon(color=color_work, icon=icon_work)
).add_to(m)

folium.Marker(
    [59.961646, 29.415822], 
    popup="<b>Lebyazhye</b><br>June 2015", 
    tooltip=tooltip, 
    icon=folium.Icon(color=color_home, icon=icon_home)
).add_to(m)

folium.Marker(
    [59.972699, 29.332709], 
    popup="<b>Fort Krasnaya Gorka</b><br>June 2015", 
    tooltip=tooltip, 
    icon=folium.Icon(color=color_home, icon=icon_home)
).add_to(m)

folium.Marker(
    [60.514869, 29.723454], 
    popup="<b>Korobitsyno</b><br>December 2016", 
    tooltip=tooltip, 
    icon=folium.Icon(color=color_home, icon=icon_home)
).add_to(m)

folium.Marker(
    [60.125495, 31.073795], 
    popup="<b>Ladozhskoye Ozero</b><br>January 2017", 
    tooltip=tooltip, 
    icon=folium.Icon(color=color_home, icon=icon_home)
).add_to(m)

folium.Marker(
    [60.068705, 31.067436], 
    popup="<b>Kokkorevo</b><br>January 2017", 
    tooltip=tooltip, 
    icon=folium.Icon(color=color_home, icon=icon_home)
).add_to(m)

folium.Marker(
    [60.086581, 31.023509], 
    popup="<b>Vaganovo</b><br>January 2017", 
    tooltip=tooltip, 
    icon=folium.Icon(color=color_home, icon=icon_home)
).add_to(m)

folium.Marker(
    [59.316293, 29.907420], 
    popup="<b>Batovo</b><br>June 2017", 
    tooltip=tooltip, 
    icon=folium.Icon(color=color_home, icon=icon_home)
).add_to(m)

folium.Marker(
    [59.322303, 29.892540], 
    popup="<b>Daymishche</b><br>June 2017", 
    tooltip=tooltip, 
    icon=folium.Icon(color=color_home, icon=icon_home)
).add_to(m)

folium.Marker(
    [59.811971, 30.573632], 
    popup="<b>Metallostroy</b><br>May 2018", 
    tooltip=tooltip, 
    icon=folium.Icon(color=color_home, icon=icon_home)
).add_to(m)

folium.Marker(
    [59.804076, 30.603509], 
    popup="<b>Ust-Izhora</b><br>November 2020", 
    tooltip=tooltip, 
    icon=folium.Icon(color=color_home, icon=icon_home)
).add_to(m)

folium.Marker(
    [59.755959, 31.051356], 
    popup="<b>Mga</b><br>August 2020", 
    tooltip=tooltip, 
    icon=folium.Icon(color=color_home, icon=icon_home)
).add_to(m)

folium.Marker(
    [59.756459, 30.972632], 
    popup="<b>Gory</b><br>August 2020", 
    tooltip=tooltip, 
    icon=folium.Icon(color=color_home, icon=icon_home)
).add_to(m)

folium.Marker(
    [59.810261, 30.895841], 
    popup="<b>Pavlovo</b><br>August 2020", 
    tooltip=tooltip, 
    icon=folium.Icon(color=color_home, icon=icon_home)
).add_to(m)

folium.Marker(
    [61.120024, 29.869007], 
    popup="<b>Kuznechnoye</b><br>June 2020", 
    tooltip=tooltip, 
    icon=folium.Icon(color=color_home, icon=icon_home)
).add_to(m)

folium.Marker(
    [60.164334, 30.540774], 
    popup="<b>Toksovo</b><br>August 2021", 
    tooltip=tooltip, 
    icon=folium.Icon(color=color_home, icon=icon_home)
).add_to(m)

folium.Marker(
    [60.020719, 30.64572], 
    popup="<b>Vsevolozhsk</b><br>September 2021", 
    tooltip=tooltip, 
    icon=folium.Icon(color=color_home, icon=icon_home)
).add_to(m)

folium.Marker(
    [59.738804, 29.750589], 
    popup="<b>Bol'shoye Zabrod'ye</b><br>January 2022", 
    tooltip=tooltip, 
    icon=folium.Icon(color=color_home, icon=icon_home)
).add_to(m)

folium.Marker(
    [42.878090, 74.612549], 
    popup="<b>Bishkek</b><br>March 2022", 
    tooltip=tooltip, 
    icon=folium.Icon(color=color_travel, icon=icon_travel)
).add_to(m)

folium.Marker(
    [40.186076, 44.515089], 
    popup="<b>Yerevan</b><br>April 2022", 
    tooltip=tooltip, 
    icon=folium.Icon(color=color_living, icon=icon_living)
).add_to(m)

folium.Marker(
    [39.878290, 44.576428], 
    popup="<b>Khor Virap</b><br>April 2022", 
    tooltip=tooltip, 
    icon=folium.Icon(color=color_travel, icon=icon_travel)
).add_to(m)

folium.Marker(
    [39.740772, 44.829733], 
    popup="<b>Yeraskh</b><br>April 2022", 
    tooltip=tooltip, 
    icon=folium.Icon(color=color_travel, icon=icon_travel)
).add_to(m)

folium.Marker(
    [39.684744, 45.233010], 
    popup="<b>Noravank</b><br>April 2022", 
    tooltip=tooltip, 
    icon=folium.Icon(color=color_travel, icon=icon_travel)
).add_to(m)

folium.Marker(
    [39.764008, 45.333238], 
    popup="<b>Yeghegnadzor</b><br>April 2022", 
    tooltip=tooltip, 
    icon=folium.Icon(color=color_travel, icon=icon_travel)
).add_to(m)

folium.Marker(
    [39.412256, 46.293627], 
    popup="<b>Halidzor</b><br>April 2022", 
    tooltip=tooltip, 
    icon=folium.Icon(color=color_travel, icon=icon_travel)
).add_to(m)

folium.Marker(
    [39.379510, 46.250143], 
    popup="<b>Tatev</b><br>April 2022", 
    tooltip=tooltip, 
    icon=folium.Icon(color=color_travel, icon=icon_travel)
).add_to(m)

folium.Marker(
    [39.501253, 46.433883], 
    popup="<b>Khndzoresk</b><br>April 2022", 
    tooltip=tooltip, 
    icon=folium.Icon(color=color_travel, icon=icon_travel)
).add_to(m)

folium.Marker(
    [39.690259, 45.468525], 
    popup="<b>Vayk</b><br>April 2022", 
    tooltip=tooltip, 
    icon=folium.Icon(color=color_travel, icon=icon_travel)
).add_to(m)

folium.Marker(
    [40.590901, 44.357533], 
    popup="<b>Aparan</b><br>May 2022", 
    tooltip=tooltip, 
    icon=folium.Icon(color=color_travel, icon=icon_travel)
).add_to(m)

folium.Marker(
    [41.005236, 44.634970], 
    popup="<b>Kopayr</b><br>May 2022", 
    tooltip=tooltip, 
    icon=folium.Icon(color=color_travel, icon=icon_travel)
).add_to(m)

folium.Marker(
    [41.050982, 44.616199], 
    popup="<b>Odzun</b><br>May 2022", 
    tooltip=tooltip, 
    icon=folium.Icon(color=color_travel, icon=icon_travel)
).add_to(m)

folium.Marker(
    [41.035175, 44.627274], 
    popup="<b>Horomayr</b><br>May 2022", 
    tooltip=tooltip, 
    icon=folium.Icon(color=color_travel, icon=icon_travel)
).add_to(m)

folium.Marker(
    [41.091856, 44.656903], 
    popup="<b>Alaverdi</b><br>May 2022", 
    tooltip=tooltip, 
    icon=folium.Icon(color=color_travel, icon=icon_travel)
).add_to(m)

folium.Marker(
    [41.093735, 44.711651], 
    popup="<b>Haghpat</b><br>May 2022", 
    tooltip=tooltip, 
    icon=folium.Icon(color=color_travel, icon=icon_travel)
).add_to(m)

folium.Marker(
    [40.547910, 44.958926], 
    popup="<b>Sevan</b><br>May 2022", 
    tooltip=tooltip, 
    icon=folium.Icon(color=color_travel, icon=icon_travel)
).add_to(m)

folium.Marker(
    [40.432781, 45.107905], 
    popup="<b>Hayravank</b><br>May 2022", 
    tooltip=tooltip, 
    icon=folium.Icon(color=color_travel, icon=icon_travel)
).add_to(m)

folium.Marker(
    [44.817031, 20.458710], 
    popup="<b>Belgrade</b><br>June 2022", 
    tooltip=tooltip, 
    icon=folium.Icon(color=color_living, icon=icon_living)
).add_to(m)

folium.Marker(
    [45.117230, 19.406807], 
    popup="<b>Erdevik</b><br>September 2022", 
    tooltip=tooltip, 
    icon=folium.Icon(color=color_travel, icon=icon_travel)
).add_to(m)

folium.Marker(
    [1.281071, 103.847476], 
    popup="<b>Singapore</b><br>November, 2022", 
    tooltip=tooltip, 
    icon=folium.Icon(color=color_work, icon=icon_work)
).add_to(m)

folium.Marker(
    [59.355381, 17.945656], 
    popup="<b>Stockholm</b><br>November 2012", 
    tooltip=tooltip, 
    icon=folium.Icon(color=color_transit, icon=icon_transit)
).add_to(m)

folium.Marker(
    [50.050418, 8.571717], 
    popup="<b>Fraknfurt am Main</b><br>November 2012", 
    tooltip=tooltip, 
    icon=folium.Icon(color=color_transit, icon=icon_transit)
).add_to(m)

folium.Marker(
    [25.271117, 51.609183], 
    popup="<b>Doha</b><br>November 2016", 
    tooltip=tooltip, 
    icon=folium.Icon(color=color_transit, icon=icon_transit)
).add_to(m)

folium.Marker(
    [25.249330, 55.352934], 
    popup="<b>Dubai</b><br>December 2016", 
    tooltip=tooltip, 
    icon=folium.Icon(color=color_transit, icon=icon_transit)
).add_to(m)

folium.Marker(
    [53.891040, 27.550887], 
    popup="<b>Minsk</b><br>August 2018", 
    tooltip=tooltip, 
    icon=folium.Icon(color=color_transit, icon=icon_transit)
).add_to(m)

folium.Marker(
    [34.870473, 33.608815], 
    popup="<b>Larnaca</b><br>December, 2022", 
    tooltip=tooltip, 
    icon=folium.Icon(color=color_work, icon=icon_work)
).add_to(m)

folium.Marker(
    [34.672267, 33.041601], 
    popup="<b>Limassol</b><br>December, 2022", 
    tooltip=tooltip, 
    icon=folium.Icon(color=color_work, icon=icon_work)
).add_to(m)

folium.Marker(
    [34.707135, 33.087090], 
    popup="<b>Germasogeia</b><br>December, 2022", 
    tooltip=tooltip, 
    icon=folium.Icon(color=color_travel, icon=icon_travel)
).add_to(m)

folium.Marker(
    [34.664499, 32.887530], 
    popup="<b>Episkopi</b><br>December, 2022", 
    tooltip=tooltip, 
    icon=folium.Icon(color=color_travel, icon=icon_travel)
).add_to(m)

folium.Marker(
    [34.603809, 32.952606], 
    popup="<b>Akrotiri</b><br>December, 2022", 
    tooltip=tooltip, 
    icon=folium.Icon(color=color_travel, icon=icon_travel)
).add_to(m)

folium.Marker(
    [34.714060, 33.140423], 
    popup="<b>Agios Tychonas</b><br>December, 2022", 
    tooltip=tooltip, 
    icon=folium.Icon(color=color_travel, icon=icon_travel)
).add_to(m)

folium.Marker(
    [34.755996, 33.093834], 
    popup="<b>Foinikaria</b><br>December, 2022", 
    tooltip=tooltip, 
    icon=folium.Icon(color=color_travel, icon=icon_travel)
).add_to(m)

folium.Marker(
    [34.689343, 33.008743], 
    popup="<b>Kato Polemidia</b><br>December, 2022", 
    tooltip=tooltip, 
    icon=folium.Icon(color=color_travel, icon=icon_travel)
).add_to(m)

folium.Marker(
    [44.984613, 20.158889], 
    popup="<b>Stara Pazova</b><br>January, 2023", 
    tooltip=tooltip, 
    icon=folium.Icon(color=color_travel, icon=icon_travel)
).add_to(m)

folium.Marker(
    [-37.817952, 144.968617], 
    popup="<b>Melbourne</b><br>May, 2023", 
    tooltip=tooltip, 
    icon=folium.Icon(color=color_work, icon=icon_work)
).add_to(m)

# %%
m.save("../talkmap/map.html")
